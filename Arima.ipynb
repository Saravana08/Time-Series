# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font='IPAGothic')
import numpy as np
import statsmodels.api as sm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-599137116c34> in <module>
#       6 sns.set(font='IPAGothic')
#       7 import numpy as np
# ----> 8 import statsmodels.api as sm
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
import os
os.chdir('C://Users//saravana.ayyappa//Desktop//Machine Learning//Data')
import pandas as pd

data=pd.read_csv('Sales.csv',index_col=[1])
data.head()
# Out:
#             Fiscal_Week  Onlineunit     Visits  Offline_Units_Queue    Calls  \
# Date
# 05-01-2015  FY15 Q1 W01     22336.0  2850927.0                  NaN  12997.0
# 12-01-2015  FY15 Q1 W02     24637.0  2940060.0                  NaN  14333.0
# 19-01-2015  FY15 Q1 W03     33898.0  3218101.0                  NaN  16209.0
# 26-01-2015  FY15 Q1 W04     21764.0  2916134.0                  NaN  12179.0
# 02-02-2015  FY15 Q1 W05     23002.0  3090675.0                  NaN  12388.0
#
#                Cat_DM    aff_pl      OA_LU  Search_LU   PRU_log  ...  \
# Date                                                             ...
# 05-01-2015  4300000.0  211519.0   759142.0   558487.0  6.552508  ...
# 12-01-2015  4300000.0  213968.0  1041246.0   629141.0  6.552508  ...
# 19-01-2015        0.0  268325.0   739661.0   705070.0  6.470800  ...
# 26-01-2015        0.0  209867.0   652412.0   592983.0  6.591674  ...
# 02-02-2015        0.0  231700.0   541207.0   474094.0  6.590301  ...
#
#             Green_Monday_Online  JBF_Online.Offline_Units  Memorial_Day  \
# Date
# 05-01-2015                  0.0                       0.0           0.0
# 12-01-2015                  0.0                       0.0           0.0
# 19-01-2015                  0.0                       0.0           0.0
# 26-01-2015                  0.0                       0.0           0.0
# 02-02-2015                  0.0                       0.0           0.0
#
#             Pre.Memorial_OnlineUnits  Q3_Decline_Flag  Q2wk1_decline  \
# Date
# 05-01-2015                       0.0              0.0            0.0
# 12-01-2015                       0.0              0.0            0.0
# 19-01-2015                       0.0              0.0            0.0
# 26-01-2015                       0.0              0.0            0.0
# 02-02-2015                       0.0              0.0            0.0
#
#             Aff_Transf_till20Q1  LT_2_onlineunits  LT_1__onlineunits  OA_Cap
# Date
# 05-01-2015                  0.0               0.0                0.0     0.0
# 12-01-2015                  0.0               0.0                0.0     0.0
# 19-01-2015                  0.0               0.0                0.0     0.0
# 26-01-2015                  0.0               0.0                0.0     0.0
# 02-02-2015                  0.0               0.0                0.0     0.0
#
# [5 rows x 28 columns]

# %%
np.asarray(data)
# Out:
# array([['FY15 Q1 W01', 22336.0, 2850927.0, ..., 0.0, 0.0, 0.0],
#        ['FY15 Q1 W02', 24637.0, 2940060.0, ..., 0.0, 0.0, 0.0],
#        ['FY15 Q1 W03', 33898.0, 3218101.0, ..., 0.0, 0.0, 0.0],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
arimax = sm.tsa.statespace.SARIMAX(data['Onlineunit'],order=(7,1,7)).fit()
arimax.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b95cea3a0e0d> in <module>
# ----> 1 arimax = sm.tsa.statespace.SARIMAX(data['Onlineunit'],order=(7,1,7)).fit()
#       2 arimax.summary()
#
# NameError: name 'sm' is not defined
